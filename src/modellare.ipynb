# %%
# !pip install torch torchvision torchaudio
import torch
import torch.nn as nn
import torchvision.transforms.functional as TF
# Out:
# Requirement already satisfied: torch in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (1.11.0)
# Requirement already satisfied: torchvision in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (0.12.0)
# Collecting torchaudio
#   Downloading torchaudio-0.11.0-cp39-cp39-macosx_11_0_arm64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 2.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from torch) (4.1.1)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from torchvision) (9.1.1)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from torchvision) (1.22.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests->torchvision) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (from requests->torchvision) (3.3)
# Installing collected packages: torchaudio
# Successfully installed torchaudio-0.11.0

# %% [markdown]
# # Tecniche di modellazione per l'apprendimento automatico

# %% [markdown]
# ## La discesa del gradiente e la rete neurale

# %% [markdown]
# ## Tecniche per la modellazione di immagini

# %%
# !pip install pillow
from PIL import Image
# open the image file for reading
img = Image.open('../res/me.jpg')
img = img.crop((0, 0, 1024, 1024))
img = img.resize((512, 512))
import numpy as np
img_array = np.array(img)

# convert the numpy array to a PIL image
img_pil = Image.fromarray(img_array)

# display the image in the notebook
display(img_pil)
# Out:
# Requirement already satisfied: pillow in /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages (9.1.1)
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
# print the size of the image
print(img_array.shape)
# convert the numpy array to a pytorch tensor
img_tensor = TF.to_tensor(img_array).unsqueeze(0)
print(img_tensor.shape)
# Out:
# (512, 512, 3)
# torch.Size([1, 3, 512, 512])

# %%
# define a filter with convolutional layers
filter1 = nn.Conv2d(
    in_channels=3,
    out_channels=1, 
    kernel_size=5,
    padding=2,
)
print(img_tensor.shape)

# apply filter 1 to the image
img_tensor_filter1 = filter1(img_tensor)
print(img_tensor_filter1.shape)

# display the filtered image
img_filter1 = TF.to_pil_image(img_tensor_filter1.squeeze(0))
display(img_filter1)

# define a reduce filter to reduce the image
reduce1 = nn.MaxPool2d(
    kernel_size=(4, 4),
)

# apply the reduce filter to the image
print(img_tensor_filter1.shape)
img_tensor_reduce1 = reduce1(img_tensor_filter1)
print(img_tensor_reduce1.shape)

# display the reduced image
img_reduce1 = TF.to_pil_image(img_tensor_reduce1.squeeze(0))
display(img_reduce1)
# Out:
# torch.Size([1, 3, 512, 512])
# torch.Size([1, 1, 512, 512])
# <PIL.Image.Image image mode=L size=512x512>
# torch.Size([1, 1, 512, 512])
# torch.Size([1, 1, 128, 128])
# <PIL.Image.Image image mode=L size=128x128>
